# %%
import sys
print(sys.executable)
print(sys.version)

#<path> -m pip install numpy
#<path> -m pip install pandas
#<path> -m pip install matplotlib
#<path> -m pip install gensim 
#<path> -m pip install tensorflow
# Out:
# c:\Users\srividhya.sundaram\AppData\Local\Programs\Python\Python312\python.exe
# 3.12.7 (tags/v3.12.7:0b05ead, Oct  1 2024, 03:06:41) [MSC v.1941 64 bit (AMD64)]
